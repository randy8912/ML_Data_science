# %% [markdown]
# ## Introduction to Matplotlib

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.plot()
# Out:
# []

# %%
plt.plot();

# %%
plt.plot()
plt.show()

# %%
plt.plot([1, 2, 3, 4]);

# %%
x = [1, 2, 3, 4]
y = [11, 22, 33, 44]
plt.plot(x, y);

# %%
plt.plot([1, 2, 3, 4]);
plt.ylabel('some numbers');
plt.show()

# %%
plt.plot([1, 2, 3, 4, 5], [100, 200, 300, 400, 500]);
plt.xlabel('Number of people collecting');
plt.ylabel('Amount of apples collected');

# %%
# 1st method
fig = plt.figure() # Creates a figure
ax = fig.add_subplot() # This adds some axes
plt.show()

# %%
# 2nd method
fig = plt.figure() # Creates a figure
ax = fig.add_axes([1, 1, 1, 1])
ax.plot(x, y) # Add some data
plt.show;

# %%
# 3rd method (recommended)
fig, ax = plt.subplots()
ax.plot(x, [50, 100, 200, 250]); # Add some data
type(fig), type(ax)
# Out:
# (matplotlib.figure.Figure, matplotlib.axes._axes.Axes)

# %% [markdown]
# <img src = "images/matplotlib_anatomy.png"/>

# %% [markdown]
# ## Matplotlib example workflow

# %%
# step zero is to import matplotlib and get it ready for plotting in Jupyter
# %matplotlib inline
import matplotlib.pyplot as plt

# 1. prepare data
x = [1, 2, 3, 4]
y = [11, 22, 33, 44]

# 2. setup plot
fig, ax = plt.subplots(figsize = (10, 10)) #(width, height)

# 3. plot data
ax.plot(x, y)

# 4. customize plots
ax.set(title = "Simple plot",
      xlabel = "x-axis",
      ylabel = "y-axis")

# 5. save & show (you save the whole figure)
fig.savefig("images/sample-plot.png")

# %% [markdown]
# ## Making figures with NumPy arrays
#
# We want:
# * Line plot
# * Scatter plot
# * Bar plot
# * Histogram
# * Subplots

# %%
import numpy as np

# %%
# Create some data 
x = np.linspace(0, 10, 100)
x[:10]
# Out:
# array([0.        , 0.1010101 , 0.2020202 , 0.3030303 , 0.4040404 ,
#        0.50505051, 0.60606061, 0.70707071, 0.80808081, 0.90909091])

# %%
# Plot the data and create a line plot
fig, ax = plt.subplots()
ax.plot(x, x**2);

# %%
# Use the same data for a Scatter plot (lots of dots)
fig, ax = plt.subplots()
ax.scatter(x, np.exp(x));

# %%
# Another scatter plot
fig, ax = plt.subplots()
ax.scatter(x, np.sin(x))

# %%
# Maker a plot from dictionary
nut_butter_prices = {"Almond butter":10,
                    "Peanut butter":8,
                    "Cashew butter":12}
fig, ax = plt.subplots()
ax.bar(nut_butter_prices.keys(), nut_butter_prices.values()) 
ax.set(title="Randy's Nut Butter Store",
      ylabel="Price ($)");

# %%
queso_prices = {"dikke kaas":14,
               "dunne kaas":8,
               "half dikke kaas":11}
fig, ax = plt.subplots()
ax.bar(queso_prices.keys(), queso_prices.values())
ax.set(title="De queso winkel",
      ylabel="Price in peseta's");

# %%
queso_prices
# Out:
# {'dikke kaas': 14, 'dunne kaas': 8, 'half dikke kaas': 11}

# %%
fig, ax = plt.subplots()
ax.barh(list(nut_butter_prices.keys()), list(nut_butter_prices.values()));

# %%
# Make some data for Histograms and plot it
x = np.random.randn(1000)
fix, ax = plt.subplots()
ax.hist(x);

# %% [markdown]
# ## Two options for subplots

# %%
# Subplot option 1
fig,((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2,
                                           ncols=2,
                                           figsize=(10, 5))

# Plot to each different axis
ax1.plot(x, x/2)
ax2.scatter(np.random.random(10), np.random.random(10))
ax3.bar(nut_butter_prices.keys(), nut_butter_prices.values())
ax4.hist(np.random.randn(1000));

# %%
# Subplot option 2
fig, ax = plt.subplots(nrows=2,
                      ncols=2,
                      figsize=(10,5))
# Plot to each different index
ax[0,0].plot(x, x/2);
ax[0,1].scatter(np.random.random(10), np.random.random(10));
ax[1,0].bar(nut_butter_prices.keys(), nut_butter_prices.values());
ax[1,1].hist(np.random.random(1000));

# %% [markdown]
# ## Plotting from pandas DataFrames

# %%
import pandas as pd
import numpy as np

# %%
# Make a dataframe

car_sales = pd.read_csv("car-sales .csv", delimiter = ";") # I used Delimiter to cut the ugly ";" out.

# car_sales['Price'] = '$' + car_sales['Price'].astype(str) # I added a "$" sign in front of every value in the "Price" column because it looks nicer.
car_sales
# Out:
#      Make Colour  Odometer  Doors  Price
# 0  Toyota  White    150043      4   4000
# 1   Honda    Red     87899      4   5000
# 2  Toyota   Blue     92549      3   7000
# 3     BMW  Black     11179      5  22000
# 4  Nissan  White    213095      4   3500
# 5  Toyota  Green     99213      4   4500
# 6   Honda   Blue     45698      4   7500
# 7   Honda   Blue     54738      4   7000
# 8  Toyota  White     60000      4   6250
# 9  Nissan  White     31600      4   9700

# %%
ts = pd.Series(np.random.randn(1000),
              index=pd.date_range("1/1/2022", periods=1000))
ts = ts.cumsum()
ts
ts.plot()
# Out:
# <Axes: >

# %%
# car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]', '')
print(type(car_sales["Price"]))
# Out:
# <class 'pandas.core.series.Series'>

# %%
car_sales["Sale date"] = pd.date_range("1/1/2020",periods=len(car_sales))
car_sales
# Out:
#      Make Colour  Odometer  Doors  Price  Sale date
# 0  Toyota  White    150043      4   4000 2020-01-01
# 1   Honda    Red     87899      4   5000 2020-01-02
# 2  Toyota   Blue     92549      3   7000 2020-01-03
# 3     BMW  Black     11179      5  22000 2020-01-04
# 4  Nissan  White    213095      4   3500 2020-01-05
# 5  Toyota  Green     99213      4   4500 2020-01-06
# 6   Honda   Blue     45698      4   7500 2020-01-07
# 7   Honda   Blue     54738      4   7000 2020-01-08
# 8  Toyota  White     60000      4   6250 2020-01-09
# 9  Nissan  White     31600      4   9700 2020-01-10

# %%
car_sales["Total Sales"] = car_sales["Price"].cumsum()
car_sales
# Out:
#      Make Colour  Odometer  Doors  Price  Sale date  Total Sales
# 0  Toyota  White    150043      4   4000 2020-01-01         4000
# 1   Honda    Red     87899      4   5000 2020-01-02         9000
# 2  Toyota   Blue     92549      3   7000 2020-01-03        16000
# 3     BMW  Black     11179      5  22000 2020-01-04        38000
# 4  Nissan  White    213095      4   3500 2020-01-05        41500
# 5  Toyota  Green     99213      4   4500 2020-01-06        46000
# 6   Honda   Blue     45698      4   7500 2020-01-07        53500
# 7   Honda   Blue     54738      4   7000 2020-01-08        60500
# 8  Toyota  White     60000      4   6250 2020-01-09        66750
# 9  Nissan  White     31600      4   9700 2020-01-10        76450

# %%
# Let's plot the total sales
car_sales.plot(x="Sale date", y="Total Sales");

# %%
car_sales.plot(x= "Odometer", y="Price", kind="scatter");

# %%
# How about a bar graph
x = np.random.randn(10,4)
x

# Turn it into a DataFrame
df = pd.DataFrame(x, columns=['a','b','c','d' ])
df
# Out:
#           a         b         c         d
# 0  0.007273 -0.556484  0.021946  0.651011
# 1  0.649136 -0.787336 -0.982000  0.573091
# 2  0.817233 -0.296846  0.382625  0.728699
# 3  0.186446  0.259676 -0.279419 -0.265523
# 4 -0.112801  0.284247 -0.325418 -0.840789
# 5 -1.064174 -1.444850  1.336943  0.614506
# 6 -0.137182  0.136101  0.590151  0.109612
# 7  0.188797  1.402224  0.323139  0.916813
# 8  0.730104  0.281696  1.205587  0.058889
# 9 -0.328128 -0.440492 -1.181947  0.338556

# %%
# Option 1 to make an bar graph from a pandas dataframe

df.plot.bar();

# %%
# Option 2 to make an bar graph from a pandas dataframe


df.plot(kind="bar");

# %%
car_sales.plot.bar();

# %%
car_sales.plot(kind="bar");

# %%
car_sales.plot(x="Make", y="Odometer", kind="bar");

# %%
# How about histograms which are good for distributions

car_sales["Odometer"].plot.hist();

# %%
# Doing the same thing using another way to make a histogram

car_sales["Odometer"].plot(kind="hist");

# %%
# Let's try on another data set
heart_disease = pd.read_csv('heart-disease.csv')
heart_disease
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
# Create a histogram of age
heart_disease["age"].plot.hist(bins=10);

# %%
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heart_disease.plot.hist(figsize=(10,30), subplots=True);

# %% [markdown]
# ### Which one should I use? (Pyplot vs matplotlib)
#
# * When plotting something quickly, it's okay to use the pyplot method
# * When plotting something more advanced, use the OO method (object oriented(more dynamic))

# %%
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
# Create a var with patients over 50, 
# from heart_disease[heart_disease["age"]>50]

over_50 = heart_disease[heart_disease["age"]>50] 
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
# OO mixed with Pyplot method 
# Plotting directly from pandas dataframe with plot

over_50.plot(kind='scatter', # Type of plot
            x='age',         # Define x-axis
            y='chol',        # Define y-axis
            c='target',
            figsize=(10,6));     # Define plot.color

# %%
import matplotlib.pyplot as plt

# %%
# The O(bject)O(riented) Method
fig, ax = plt.subplots(figsize=(10,6)) # Figure size parameter
over_50.plot(kind='scatter',           # Kind of plot parameter
            x='age',                   # x-axis parameter
            y='chol',                  # y-axis parameter
            c='target',                # Color parameter
            ax=ax);                    # Refer to ax parameter

# ax.set_xlim([45, 100])                 # Use ax.set_xlim ([]) to reset the ax limit from 45 to 100

# %% [markdown]
# ## O(bject) O(riented) method from scratch

# %%
fig, ax = plt.subplots(figsize=(10, 6))

# Plot the data
scatter = ax.scatter(x=over_50["age"], # Check 100 times if the module definition is on point (frustration= -1000000)
                     y=over_50["chol"],
                     c=over_50["target"])

# Customize the plot
ax.set(title="Heart disease and Cholesterol Levels",
      xlabel="Age",
      ylabel="Cholesterol");

# Add a legend
ax.legend(*scatter.legend_elements(), title="Target");

# Add a horizontal line
ax.axhline(over_50["chol"].mean(),
          linestyle="--"); # Gives a horizontal line across the mean of the "chol" column

# %%
# Subplot of hol, age, thalach

fig, (ax0, ax1) = plt.subplots(nrows=2,
                              ncols=1,
                              figsize=(10,10),
                              sharex=True)


# Add data to ax0
scatter = ax0.scatter(x=over_50["age"],
                     y=over_50["chol"],
                     c=over_50["target"])
# Customize ax0:
ax0.set(title="Heart Disease and Cholesterol Levels",
       ylabel="Cholesterol");

# Add a legend to ax0
ax0.legend(*scatter.legend_elements(), title="Target")

# Add a mean line
ax0.axhline(y=over_50["chol"].mean(),
           linestyle="--");

# Do the same for ax1 but switch "chol" to "thalach"

# Add data to ax1
scatter = ax1.scatter(x=over_50["age"],
                     y=over_50["thalach"],
                     c=over_50["target"])
# Customize ax1:
ax1.set(title="Heart Disease and Thalach(Max Heart rate)",
        xlabel="Age",
       ylabel="Thalach(Max Heart rate)");

# Add a legend to ax1
ax1.legend(*scatter.legend_elements(), title="Target")

# Add a mean line
ax1.axhline(y=over_50["thalach"].mean(),
           linestyle="--");

# Add a title to the figure
fig.suptitle("Heart Disease Analysis", fontsize=16, fontweight="bold");

# %% [markdown]
# # Workflow oo method:
# * Create a figure
# * Define the axes
# * Customize axes
# * Add titles to axes
# * Add Figure title

# %% [markdown]
# ## Sidenote: I find the OO method way beter because you can customize every variable on demand.
# * This gives you way more control over it's variables!!!

# %% [markdown]
# ## What I've learned
# * oo Method gives you more control in creating plots because you can set all of it's variables
# * I've learned the most efficient workflow in creating a plot using the object oriented method:
#     * Plot the data
#     * Customize the plot
#     * Add a legend
#     * Add horizontal customized line to the plot using linestyle="--"
#
#
# ### Things to keep in mind:
# * Pay notice to the syntax (mistakes are easily made and hard to detect in this stage of my development)

# %% [markdown]
# ## Customizing matplotlib plots and getting stylish

# %%
# See the different styles available (plot styles)
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer  Doors  Price  Sale date  Total Sales
# 0  Toyota  White    150043      4   4000 2020-01-01         4000
# 1   Honda    Red     87899      4   5000 2020-01-02         9000
# 2  Toyota   Blue     92549      3   7000 2020-01-03        16000
# 3     BMW  Black     11179      5  22000 2020-01-04        38000
# 4  Nissan  White    213095      4   3500 2020-01-05        41500

# %%
car_sales["Price"].plot();

# %%
plt.style.use('seaborn-v0_8-whitegrid')

# %%
car_sales["Price"].plot();

# %%
plt.style.use("seaborn-v0_8")

# %%
car_sales["Price"].plot();

# %%
car_sales.plot(x="Odometer", y="Price", kind="scatter");

# %%
plt.style.use("ggplot")
car_sales["Price"].plot();

# %%
# Create some data
x = np.random.randn(10,4)
x
# Out:
# array([[-0.09287262, -0.28288025,  0.07608897, -1.07140663],
#        [ 0.88351329, -0.10457054,  0.84343676, -2.43047613],
#        [ 0.51735358,  0.35221365, -1.32297777,  1.32954844],
#        [ 1.68984444,  0.89067149, -0.4391193 , -0.00981926],
#        [ 1.03735984,  0.56274024, -1.00045723,  1.94731366],
#        [ 2.01647992,  1.44704388,  0.58768156, -0.29641089],
#        [-0.52758515, -0.24782641,  0.5039777 , -1.20424833],
#        [-1.32305551, -0.97834656, -1.48425822,  1.34084269],
#        [ 0.31109937, -0.26223904, -0.45460911, -0.39335352],
#        [-0.54346885,  2.00317818,  0.87974433, -0.41886676]])

# %%
df = pd.DataFrame(x, columns=['a', 'b', 'c', 'd'])
df
# Out:
#           a         b         c         d
# 0 -0.092873 -0.282880  0.076089 -1.071407
# 1  0.883513 -0.104571  0.843437 -2.430476
# 2  0.517354  0.352214 -1.322978  1.329548
# 3  1.689844  0.890671 -0.439119 -0.009819
# 4  1.037360  0.562740 -1.000457  1.947314
# 5  2.016480  1.447044  0.587682 -0.296411
# 6 -0.527585 -0.247826  0.503978 -1.204248
# 7 -1.323056 -0.978347 -1.484258  1.340843
# 8  0.311099 -0.262239 -0.454609 -0.393354
# 9 -0.543469  2.003178  0.879744 -0.418867

# %%
ax = df.plot(kind='bar')
type(ax);

# %%
# Customize out plot with the set() method
ax = df.plot(kind='bar')
# Add some labels and a title
ax.set(title="Random Number Bar Graph from DataFrame",
      xlabel="Row number",
      ylabel="Random number");
# Make the legend visible
ax.legend().set_visible(True)

# %%
# Set the style
plt.style.use('seaborn-v0_8-whitegrid')

# Subplot of hol, age, thalach

fig, (ax0, ax1) = plt.subplots(nrows=2,
                              ncols=1,
                              figsize=(10,10),
                              sharex=True)


# Add data to ax0
scatter = ax0.scatter(x=over_50["age"],
                     y=over_50["chol"],
                     c=over_50["target"],
                     cmap="winter")
# Customize ax0:
ax0.set(title="Heart Disease and Cholesterol Levels",
       ylabel="Cholesterol");

# Add a legend to ax0
ax0.legend(*scatter.legend_elements(), title="Target")

# Add a horizontal line
ax0.axhline(y=over_50["chol"].mean(),
           linestyle="--");

# Do the same for ax1 but switch "chol" to "thalach"

# Add data to ax1
scatter = ax1.scatter(x=over_50["age"],
                     y=over_50["thalach"],
                     c=over_50["target"],
                     cmap="winter")
# Customize ax1:
ax1.set(title="Heart Disease and Thalach(Max Heart rate)",
        xlabel="Age",
       ylabel="Thalach(Max Heart rate)");

# Add a legend to ax1
ax1.legend(*scatter.legend_elements(), title="Target")

# Add a mean line
ax1.axhline(y=over_50["thalach"].mean(),
           linestyle="--");

# Add a title to the figure
fig.suptitle("Heart Disease Analysis", fontsize=16, fontweight="bold");

# %%
# Customizing the x and y limitations

# Set the style
plt.style.use('seaborn-v0_8-whitegrid')

# Subplot of hol, age, thalach

fig, (ax0, ax1) = plt.subplots(nrows=2,
                              ncols=1,
                              figsize=(10,10),
                              sharex=True)


# Add data to ax0
scatter = ax0.scatter(x=over_50["age"],
                     y=over_50["chol"],
                     c=over_50["target"],
                     cmap="winter")
# Customize ax0:
ax0.set(title="Heart Disease and Cholesterol Levels",
       ylabel="Cholesterol");
# Change the x axis limits
ax0.set_xlim([50,80])

# Add a legend to ax0
ax0.legend(*scatter.legend_elements(), title="Target")

# Add a horizontal line
ax0.axhline(y=over_50["chol"].mean(),
           linestyle="--");

# Do the same for ax1 but switch "chol" to "thalach"

# Add data to ax1
scatter = ax1.scatter(x=over_50["age"],
                     y=over_50["thalach"],
                     c=over_50["target"],
                     cmap="winter")
# Customize ax1:
ax1.set(title="Heart Disease and Thalach(Max Heart rate)",
        xlabel="Age",
       ylabel="Thalach(Max Heart rate)");
# Change ax1 x axis limits
ax1.set_xlim([50,80])
ax1.set_ylim([60,200])
# Add a legend to ax1
ax1.legend(*scatter.legend_elements(), title="Target")

# Add a mean line
ax1.axhline(y=over_50["thalach"].mean(),
           linestyle="--");

# Add a title to the figure
fig.suptitle("Heart Disease Analysis", fontsize=16, fontweight="bold");

# %%
fig

# %%
fig.savefig("heart-disease-analysis-plot-saved-with-code.png")
